# %% [markdown]
# # 1 Neccessary Import

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = {
    'Name':['Ali','Ahmed','Sara','Tom','Mike','Maira'],
    'Gender':['Male','Male','Female','Male','Male','Female'],
    'Age':[20,30,15,24,23,20],
    'Height':[5.2,5.4,5.1,5.5,5.6,5.0],
    'Play' : [True,True,False,True,False,True]
}

# %%
data
# Out:
# {'Name': ['Ali', 'Ahmed', 'Sara', 'Tom', 'Mike', 'Maira'],
#  'Gender': ['Male', 'Male', 'Female', 'Male', 'Male', 'Female'],
#  'Age': [20, 30, 15, 24, 23, 20],
#  'Height': [5.2, 5.4, 5.1, 5.5, 5.6, 5.0],
#  'Play': [True, True, False, True, False, True]}

# %%
type(data)
# Out:
# dict

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#     Name  Gender  Age  Height   Play
# 0    Ali    Male   20     5.2   True
# 1  Ahmed    Male   30     5.4   True
# 2   Sara  Female   15     5.1  False
# 3    Tom    Male   24     5.5   True
# 4   Mike    Male   23     5.6  False
# 5  Maira  Female   20     5.0   True

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (6, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Gender  6 non-null      object
#  2   Age     6 non-null      int64
#  3   Height  6 non-null      float64
#  4   Play    6 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 326.0+ bytes

# %%
data.head()
# Out:
#     Name  Gender  Age  Height   Play
# 0    Ali    Male   20     5.2   True
# 1  Ahmed    Male   30     5.4   True
# 2   Sara  Female   15     5.1  False
# 3    Tom    Male   24     5.5   True
# 4   Mike    Male   23     5.6  False

# %%
data.tail()
# Out:
#     Name  Gender  Age  Height   Play
# 1  Ahmed    Male   30     5.4   True
# 2   Sara  Female   15     5.1  False
# 3    Tom    Male   24     5.5   True
# 4   Mike    Male   23     5.6  False
# 5  Maira  Female   20     5.0   True

# %%
data.describe()
# Out:
#             Age    Height
# count   6.00000  6.000000
# mean   22.00000  5.300000
# std     5.01996  0.236643
# min    15.00000  5.000000
# 25%    20.00000  5.125000
# 50%    21.50000  5.300000
# 75%    23.75000  5.475000
# max    30.00000  5.600000

# %%
data.describe(include=['object'])
# Out:
#        Name Gender
# count     6      6
# unique    6      2
# top     Ali   Male
# freq      1      4

# %%
data.describe(include=['object','integer','bool','float'])
# Out:
#        Name Gender       Age    Height  Play
# count     6      6   6.00000  6.000000     6
# unique    6      2       NaN       NaN     2
# top     Ali   Male       NaN       NaN  True
# freq      1      4       NaN       NaN     4
# mean    NaN    NaN  22.00000  5.300000   NaN
# std     NaN    NaN   5.01996  0.236643   NaN
# min     NaN    NaN  15.00000  5.000000   NaN
# 25%     NaN    NaN  20.00000  5.125000   NaN
# 50%     NaN    NaN  21.50000  5.300000   NaN
# 75%     NaN    NaN  23.75000  5.475000   NaN
# max     NaN    NaN  30.00000  5.600000   NaN

# %%
data.dtypes
# Out:
# Name       object
# Gender     object
# Age         int64
# Height    float64
# Play         bool
# dtype: object

# %% [markdown]
# # Some commands to get basic statistcal measures for individual columns

# %%
data['Age'].mean()
# Out:
# 22.0

# %%
data['Age'].median()
# Out:
# 21.5

# %%
data['Age'].mode()
# Out:
# 0    20
# dtype: int64

# %%
data['Age'].max()
# Out:
# 30

# %%
data['Age'].min()
# Out:
# 15

# %%
data['Age'].var()
# Out:
# 25.2

# %%
# making quantiles

Q1 = np.quantile(data['Age'],0.25)
Q1
# Out:
# 20.0

# %%
Q2 = np.quantile(data['Age'],0.50)
Q2
# Out:
# 21.5

# %%
Q3 = np.quantile(data['Age'],0.75)
Q3
# Out:
# 23.75

# %%
# Interquartile range(IQR)
IQR = Q3 - Q1
IQR
# Out:
# 3.75

# %% [markdown]
# # Importing Data Frame

# %%
data2 = pd.read_csv('sampleCSV.csv')
data2
# Out:
#    S.NO   Name   Age   Gender
# 0     1     Ali    20     Male
# 1     2   Ahmed    21     Male
# 2     3   Usman    22     Male
# 3     4   Akram    23     Male
# 4     5     Tom    19     Male
# 5     6    Sara    17   Female
# 6     7   David    23     Male
# 7     8  Dravid    22     Male
# 8     9     Bob    18     Male
# 9    10   Clara    21  Female

# %%
data3 = pd.read_csv('TelecomChurn.csv')
data3
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# # inserting columns header
# data.columns  = ['ID','Name','Age']

# %%
data3.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data3.shape
# Out:
# (3333, 21)

# %%
pd.set_option('Display.Max_Columns',50)

# %%
data3.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
data3.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data3.describe(include='object')
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     352-9836                 no              no
# freq     106            1               3010            2411

# %%
data3['state'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OR     78
# OH     78
# VA     77
# WY     77
# CT     74
# VT     73
# ID     73
# MI     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NJ     68
# MT     68
# NC     68
# WA     66
# NV     66
# CO     66
# MA     65
# RI     65
# MS     65
# AZ     64
# MO     63
# FL     63
# ME     62
# ND     62
# NM     62
# NE     61
# OK     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: state, dtype: int64

# %%
data3['state'].value_counts().plot(kind = 'bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
data3['churn'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data3['total day charge'].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Distibution Graph

# %%
sns.distplot(data3['total day charge'],bins=100,kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total day charge', ylabel='Density'>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x='total day calls',data=data3)
# Out:
# <AxesSubplot:xlabel='total day calls'>

# %% [markdown]
# # missing value anylisis
